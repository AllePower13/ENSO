# %% [markdown]
# # TASK 10 - Gradiente Zonale - :
#
# ## Task-10_ZonalGrad:
#
# In questo Task verifico come si modifica, nell'intensità e posizione il gradiente di SST nel pacifico equatoriale, precursore sia dell'oscillazione di ENSO che fautore della sua diversita'.
#
#
# Cose da fare:
# - Definire una metrica che valuti la grandezza del gradiente zonale di SST e valutarla su un area geografica (da definire) nel pacifico
# - Individuare, quantificare e tracciare lo spostametno del massimo del gradiente
#
# ### Nota:
